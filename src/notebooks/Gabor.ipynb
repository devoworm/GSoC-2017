# %%
import sys
sys.path.append('../')
# %matplotlib inline
import python.edge as edge 
import python.GaborFilter as gabor
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
#reading and filtering the image
file= '../data/interim/spim2/c347.jpg'
img = cv2.imread(file,0)
app1 = cv2.imread(file)
filtered = cv2.bilateralFilter(img, 12,350,350)

# %%
edgeIm = ( cv2.bilateralFilter(gabor.getGabor(filtered), 12,350,350))
plt.imshow(cv2.cvtColor(edgeIm, cv2.COLOR_GRAY2RGB))

# %%
k, thres = cv2.threshold(edgeIm, 40, 255, cv2.THRESH_BINARY)
plt.imshow(cv2.cvtColor(thres, cv2.COLOR_GRAY2RGB))
